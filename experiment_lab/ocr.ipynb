# %%
from PIL import Image
import pytesseract

# Path to your image file
image_path = "./output/math.png"

# Open image
img = Image.open(image_path)

# Perform OCR using pytesseract
text = pytesseract.image_to_string(img)

print("Extracted Text:")
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\NEETengine\nenv\Lib\site-packages\pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File d:\NEETengine\nenv\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
pip install easyocr
# Out:
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------------------------- ------- 2.4/2.9 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 11.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/39.4 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/39.4 MB 11.9 MB/s eta 0:00:03
#    ------ --------------------------------- 6.8/39.4 MB 11.3 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/39.4 MB 11.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.8/39.4 MB 11.5 MB/s eta 0:00:03
#    -------------- ------------------------- 14.2/39.4 MB 11.5 MB/s eta 0:00:03
# ...

# %%
import easyocr

reader = easyocr.Reader(['en'])  # Specify language(s)
result = reader.readtext('txt.png')

for bbox, text, prob in result:
    print(f'Text: {text} (Confidence: {prob:.2f})')
# Out:
# Text: pixZtex (Confidence: 0.67)
# Text: pixztex (Confidence: 0.98)
# Text: LaTex OCR (Confidence: 0.43)
# Text: The goal of this project is to create a learning based system (Confidence: 0.71)
# Text: that takes an image of (Confidence: 0.71)
# Text: math formula and returns corresponding LaTeX code (Confidence: 0.71)
# Text: Pix2Text (P2T) (Confidence: 0.67)
# Text: https Ilpzt breezedeus com (Confidence: 0.65)
# Text: Pix2Text (P2T) - Free Mathpix Alternative (Confidence: 0.59)
# Text: Use PixzText (P2T) to convert math formulas in images to text PixzText is a free alternative to (Confidence: 0.59)
# Text: Mathpix that supports math formula recognition , (Confidence: 0.77)

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import subprocess

# %%
result = subprocess.run(
            ["pix2tex", "cal.png"],
            capture_output=True,
            text=True,
            timeout=60  # increased timeout
        )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = subprocess.run(
#       2             ["pix2tex", "cal.png"],
#       3             capture_output=True,
#       4             text=True,
#       5             timeout=60  # increased timeout
#       6         )
#
# File d:\NEETengine\nenv\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
import subprocess

result = subprocess.run(
    [r"C:\Path\To\pix2tex.exe", "cal.png"],
    capture_output=True,
    text=True,
    timeout=60
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import subprocess
# ----> 3 result = subprocess.run(
#       4     [r"C:\Path\To\pix2tex.exe", "cal.png"],
#       5     capture_output=True,
#       6     text=True,
#       7     timeout=60
#       8 )
#
# File d:\NEETengine\nenv\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
pip install numba==0.56.4
# Out:
# ...
#      ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#      ----------------- ---------------------- 1.0/2.4 MB 5.0 MB/s eta 0:00:01
#      ------------------------------ --------- 1.8/2.4 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 2.4/2.4 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       C:\Users\lenovo\AppData\Local\Temp\pip-install-91g042p_\numba_baadad12e88349cf944cf6a1c87b395b\versioneer.py:335: SyntaxWarning: invalid escape sequence '\s'
#         LONG_VERSION_PY['git'] = '''
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
# ...

# %%
pip install pix2text
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pix2text import Pix2Text

img_fp = 'cal.png'
p2t = Pix2Text.from_config()
outs = p2t.recognize_text_formula(img_fp)
print(outs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\NEETengine\nenv\Lib\site-packages\transformers\utils\import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File d:\NEETengine\nenv\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1325, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:929, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:994, in exec_module(self, module)
# ...

# %%
import cv2
image = cv2.imread("cal.png", cv2.IMREAD_GRAYSCALE)
image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
cv2.imwrite("temp.png", image)
# Out:
# True

# %%
pip install pix2tex
# Out:
# ...
#   Using cached pix2tex-0.1.4-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached x_transformers-0.15.0-py3-none-any.whl.metadata (651 bytes)
# ...
#   Using cached timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# ...
#   Using cached albumentations-1.4.24-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached entmax-1.3-py3-none-any.whl.metadata (348 bytes)
# ...
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# ...
# Using cached pix2tex-0.1.4-py3-none-any.whl (427 kB)
# Using cached timm-0.5.4-py3-none-any.whl (431 kB)
# Using cached x_transformers-0.15.0-py3-none-any.whl (11 kB)
# Using cached albumentations-1.4.24-py3-none-any.whl (274 kB)
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Using cached entmax-1.3-py3-none-any.whl (13 kB)
# ...
#
# ...

# %%
from PIL import Image
from pix2tex.cli import LatexOCR

img = Image.open('txt.png')   # Load your input image
model = LatexOCR()                      # Initialize Pix2Tex model
print(model(img))                       # Predict LaTeX and print it
# Out:
# \begin{array}{r}{{\frac{1}{\hbar m\hbar}}{\binom{k}{k}}}\\ {\int_{k=1}^{k}}\\ {\int_{k}^{k}}\\ {\cos_{k}}\end{array}

# %%
import cv2
import numpy as np
from PIL import Image

def preprocess_image(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img = cv2.threshold(img, 150, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    img = Image.fromarray(img)
    return img

# %%
from pix2tex.cli import LatexOCR

img = preprocess_image("cal.png")
model = LatexOCR()
print(model(img))
# Out:
# \Gamma[\gamma_{\mathrm{TQ}}:\mathbb{H})\oplus\operatorname{QeriNetiveor\trier\tior\tive\or\tvier\ter\trior\trier\terior\trior\the\trin\trierin\triterice}:]

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=582x48>

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=634x226>

# %%
from texify.inference import batch_inference
from texify.model.model import load_model
from texify.model.processor import load_processor
from PIL import Image

model = load_model()
processor = load_processor()
img = Image.open("cal.png") # Your image name here
results = batch_inference([img], model, processor)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\NEETengine\nenv\Lib\site-packages\transformers\utils\import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File d:\NEETengine\nenv\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1325, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:929, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:994, in exec_module(self, module)
# ...

# %%
from numba.decorators import jit

@jit
def f(x):
    return x * x

print(f(5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from numba.decorators import jit
#       3 @jit
#       4 def f(x):
#       5     return x * x
#
# ModuleNotFoundError: No module named 'numba.decorators'
